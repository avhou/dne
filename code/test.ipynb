# %%
import pandas as pd
import numpy as np
from configparser import ConfigParser

# %%
# Read the filepath from the config ini file
config = ConfigParser()
config.read('config.ini')
filepath = config.get('Data', 'SolarFilePath')

# %%
df = pd.read_csv(filepath)

# %%
filtered_df = df[(df['DateTime'] >= '26/03/2023 01:00') & (df['DateTime'] < '26/03/2023 16:00')]

# %%
filtered_df.head(10)
# Out:
#                 DateTime  Most recent forecast [MW]  Day-Ahead forecast [MW]  \
# 351456  26/03/2023 01:00                        0.0                      0.0
# 351457  26/03/2023 01:15                        0.0                      0.0
# 351458  26/03/2023 01:30                        0.0                      0.0
# 351459  26/03/2023 01:45                        0.0                      0.0
# 351460  26/03/2023 03:00                        0.0                      0.0
# 351461  26/03/2023 03:15                        0.0                      0.0
# 351462  26/03/2023 03:30                        0.0                      0.0
# 351463  26/03/2023 03:45                        0.0                      0.0
# 351464  26/03/2023 04:00                        0.0                      0.0
# 351465  26/03/2023 04:15                        0.0                      0.0
#
#         Week-Ahead forecast [MW]  Real-time Upscaled Measurement [MW]  \
# 351456                       0.0                                  0.0
# 351457                       0.0                                  0.0
# 351458                       0.0                                  0.0
# 351459                       0.0                                  0.0
# 351460                       0.0                                  0.0
# 351461                       0.0                                  0.0
# 351462                       0.0                                  0.0
# 351463                       0.0                                  0.0
# 351464                       0.0                                  0.0
# 351465                       0.0                                  0.0
#
#         Corrected Upscaled Measurement [MW]  Monitored Capacity [MWp]  \
# 351456                                  0.0                   7348.18
# 351457                                  0.0                   7348.18
# 351458                                  0.0                   7348.18
# 351459                                  0.0                   7348.18
# 351460                                  0.0                   7348.18
# 351461                                  0.0                   7348.18
# 351462                                  0.0                   7348.18
# 351463                                  0.0                   7348.18
# 351464                                  0.0                   7348.18
# 351465                                  0.0                   7348.18
#
#         Day-Ahead forecast (11h00) [MW]
# 351456                              0.0
# 351457                              0.0
# 351458                              0.0
# 351459                              0.0
# 351460                              0.0
# 351461                              0.0
# 351462                              0.0
# 351463                              0.0
# 351464                              0.0
# 351465                              0.0
